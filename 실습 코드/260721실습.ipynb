# %% [markdown]
# # 2026 07 21 Python 실습 코드

# %%
import torch
import numpy, pandas, matplotlib, sklearn, scipy
print("deepl 가상 환경 - CUDA, PyTorch")

print(torch.__version__)
print(torch.cuda.is_available())
print(torch.backends.cudnn.enabled)  # True 나와야 함
print(torch.backends.cudnn.version())  # 8902 같은 버전 숫자
print(torch.cuda.get_device_name(0))

print("numpy       :", numpy.__version__)
print("pandas      :", pandas.__version__)
print("matplotlib  :", matplotlib.__version__)
print("scikit-learn:", sklearn.__version__)
print("scipy       :", scipy.__version__)
# Out:
# deepl 가상 환경 - CUDA, PyTorch
# 2.13.0+cu132
# True
# True
# 92000
# NVIDIA GeForce RTX 4050 Laptop GPU
# numpy       : 2.4.4
# pandas      : 3.0.3
# matplotlib  : 3.11.1
# scikit-learn: 1.9.0
# scipy       : 1.18.0
