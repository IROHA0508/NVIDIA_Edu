# %% [markdown]
# # Python 문제셋
#
# 푸는 방법
# - 각 문제 아래 빈 코드 셀에 답을 작성하고 실행하세요.
# - 막히면 "정답 예시 보기"를 눌러 확인할 수 있습니다. (정답은 하나의 예시일 뿐, 다르게 풀어도 됩니다.)
#
# 난이도 안내: [초급] 개념 확인 · [중급] 응용 · [고급] 여러 개념 조합
#
# 다루는 문법: 출력(print), 입력(input)과 형변환, 이스케이프 시퀀스, 변수와 자료형, 문자열 포매팅, 연산자, 문자열, 리스트, 튜플, 딕셔너리, 세트

# %% [markdown]
# ## 1. 출력 (print)

# %% [markdown]
# **문제 1-1 [초급]**
#
# 화면에 `Hello, Python!` 을 출력하세요.

# %%
# 여기에 코드를 작성하세요
print("Hello, Python!")
# Out:
# Hello, Python!

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# print("Hello, Python!")
# ```
#
# </details>

# %% [markdown]
# **문제 1-2 [초급]**
#
# `apple`, `banana`, `cherry` 세 단어를 `sep` 옵션으로 `, `(쉼표+공백)로 이어 한 줄에 출력하세요.
#
# 출력: `apple, banana, cherry`

# %%
# 여기에 코드를 작성하세요
print("apple", "banana", "cherry", sep = ', ')
# Out:
# apple, banana, cherry

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# print("apple", "banana", "cherry", sep=", ")
# ```
#
# </details>

# %% [markdown]
# **문제 1-3 [초급]**
#
# `end` 옵션을 사용해 두 개의 print로 `HelloWorld` 를 한 줄에 붙여 출력하세요.

# %%
# 여기에 코드를 작성하세요
print("Hello", end = '')
print("World")
# Out:
# HelloWorld

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# print("Hello", end="")
# print("World")
# ```
#
# </details>

# %% [markdown]
# **문제 1-4 [중급]**
#
# `sep` 와 `end` 옵션을 사용해 `2024`, `12`, `25` 를 하이픈으로 잇고 끝에 `!` 를 붙여 한 줄로 출력하세요.
#
# 출력: `2024-12-25!`

# %%
# 여기에 코드를 작성하세요
print(2024,12,25, sep ='-', end = "!")
# Out:
# 2024-12-25!

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# print("2024", "12", "25", sep="-", end="!")
# print()
# ```
#
# </details>

# %% [markdown]
# **문제 1-5 [중급]**
#
# `print` 한 번으로 다음처럼 세 줄을 출력하세요.
# ```
# 사과
# 바나나
# 체리
# ```

# %%
# 여기에 코드를 작성하세요
print("사과", "바나나", "체리", sep = "\n")
# Out:
# 사과
# 바나나
# 체리

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# print("사과", "바나나", "체리", sep="\n")
# ```
#
# </details>

# %% [markdown]
# **문제 1-6 [중급]**
#
# `print` 한 번으로 다음을 출력하세요. (이스케이프 시퀀스 활용)
# ```
# 1 2 3
# 4 5 6
# ```

# %%
# 여기에 코드를 작성하세요
print("1 2 3 \n4 5 6")
# Out:
# 1 2 3
# 4 5 6

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# print("1 2 3\n4 5 6")
# ```
#
# </details>

# %% [markdown]
# ## 2. 입력 (input) 과 형변환

# %% [markdown]
# **문제 2-1 [초급]**
#
# 이름을 입력받아 `안녕하세요, OOO님!` 을 출력하세요.

# %%
# 여기에 코드를 작성하세요
name = input()
print(f"안녕하세요, {name}님!")
# Out:
# 안녕하세요, 이시원님!

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# name = input()
# print("안녕하세요, " + name + "님!")
# ```
#
# </details>

# %% [markdown]
# **문제 2-2 [초급]**
#
# 정수 두 개를 각각 입력받아 두 수의 합을 출력하세요.

# %%
# 여기에 코드를 작성하세요
a, b = map(int, input().split())
print(a+b)
# Out:
# 9

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# a = int(input())
# b = int(input())
# print(a + b)
# ```
#
# </details>

# %% [markdown]
# **문제 2-3 [중급]**
#
# 원의 반지름을 실수로 입력받아 넓이(`3.14 * r * r`)를 출력하세요.

# %%
# 여기에 코드를 작성하세요
rad = float(input())
print("Area : ", 3.14*rad*rad)
# Out:
# Area :  78.5

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# r = float(input())
# print(3.14 * r * r)
# ```
#
# </details>

# %% [markdown]
# **문제 2-4 [중급]**
#
# 세 과목 점수를 각각 입력받아 총점과 평균(소수점 2자리)을 출력하세요.

# %%
# 여기에 코드를 작성하세요
a,b,c = map(float, input().split())
print("총점 : %d, 평균 : %0.2f" %(int(a+b+c), (a+b+c)/3))
# Out:
# 총점 : 60, 평균 : 20.00

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# a = int(input())
# b = int(input())
# c = int(input())
# print("총점:", a + b + c)
# print("평균: %.2f" % ((a + b + c) / 3))
# ```
#
# </details>

# %% [markdown]
# **문제 2-5 [중급]**
#
# 한 줄에 공백으로 구분된 정수 두 개를 입력받아 합을 출력하세요. (예: `3 5` -> `8`)

# %%
# 여기에 코드를 작성하세요
a , b = map(int, input().split())
print(a + b)
# Out:
# 8

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# a, b = input().split()
# print(int(a) + int(b))
# ```
#
# </details>

# %% [markdown]
# **문제 2-6 [고급]**
#
# 한 줄에 공백으로 구분된 정수 5개를 입력받아, 첫 번째와 마지막 수의 합을 출력하세요. (예: `1 2 3 4 5` -> `6`)

# %%
# 여기에 코드를 작성하세요
num = list(map(int, input().split()))
print(num[0] + num[4])
# Out:
# 6

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# nums = input().split()
# print(int(nums[0]) + int(nums[4]))
# ```
#
# </details>

# %% [markdown]
# ## 3. 이스케이프 시퀀스

# %% [markdown]
# **문제 3-1 [초급]**
#
# `print` 한 번으로 `가`, `나`, `다` 를 각각 다른 줄에 출력하세요.

# %%
# 여기에 코드를 작성하세요
print('가', '나', '다', sep = '\n')
# Out:
# 가
# 나
# 다

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# print("가\n나\n다")
# ```
#
# </details>

# %% [markdown]
# **문제 3-2 [초급]**
#
# 탭(`\t`)을 사용해 다음처럼 출력하세요.
# ```
# 이름	나이
# 홍길동	13
# ```

# %%
# 여기에 코드를 작성하세요
print('이름\t나이')
print('홍길동\t13')
# Out:
# 이름	나이
# 홍길동	13

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# print("이름\t나이")
# print("홍길동\t13")
# ```
#
# </details>

# %% [markdown]
# **문제 3-3 [중급]**
#
# 다음 문장을 큰따옴표까지 포함해 출력하세요.
#
# 출력: `그는 "안녕"이라고 말했다.`

# %%
# 여기에 코드를 작성하세요
print('그는 \"안녕\"이라고 말했다')
# Out:
# 그는 "안녕"이라고 말했다

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# print("그는 \"안녕\"이라고 말했다.")
# ```
#
# </details>

# %% [markdown]
# **문제 3-4 [고급]**
#
# `print` 한 번으로 다음 계단 모양을 출력하세요.
# ```
# *
# **
# ***
# ```

# %%
# 여기에 코드를 작성하세요
print("*\n**\n***")
# Out:
# *
# **
# ***

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# print("*\n**\n***")
# ```
#
# </details>

# %% [markdown]
# ## 4. 변수와 자료형

# %% [markdown]
# **문제 4-1 [초급]**
#
# 정수 `10`, 실수 `3.14`, 문자열 `"hi"` 를 각각 변수에 담고, 세 변수의 자료형(`type`)을 출력하세요.

# %%
# 여기에 코드를 작성하세요
a = 10
b = 3.14
c = "hi"
print(type(a), type(b), type(c))
# Out:
# <class 'int'> <class 'float'> <class 'str'>

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# a = 10
# b = 3.14
# c = "hi"
# print(type(a), type(b), type(c))
# ```
#
# </details>

# %% [markdown]
# **문제 4-2 [중급]**
#
# 문자열 `"123"` 을 정수로 바꾼 뒤 1을 더해 출력하세요. (결과: `124`)

# %%
# 여기에 코드를 작성하세요
a = "123"
print(int(a) + 1)
# Out:
# 124

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# s = "123"
# print(int(s) + 1)
# ```
#
# </details>

# %% [markdown]
# **문제 4-3 [중급]**
#
# 두 변수 `a = 1`, `b = 2` 의 값을 서로 바꿔 출력하세요. (결과: `2 1`)

# %%
# 여기에 코드를 작성하세요
a = 1
b = 2
tmp = a
a = b
b = tmp
print(a , b)
# Out:
# 2 1

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# a = 1
# b = 2
# a, b = b, a
# print(a, b)
# ```
#
# </details>

# %% [markdown]
# ## 5. 문자열 포매팅

# %% [markdown]
# **문제 5-1 [초급]**
#
# 포맷 코드 `%d` 를 사용해 `7은 정수입니다.` 를 출력하세요.

# %%
# 여기에 코드를 작성하세요
print("%d는 정수입니다." %7)
# Out:
# 7는 정수입니다.

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# n = 7
# print("%d은 정수입니다." % n)
# ```
#
# </details>

# %% [markdown]
# **문제 5-2 [초급]**
#
# 포맷 코드 `%s` 를 사용해 `나는 파이썬을 좋아합니다.` 를 출력하세요. (`파이썬` 은 변수로)

# %%
# 여기에 코드를 작성하세요
a = "파이썬"
print("나는 %s을 좋아합니다." %a)
# Out:
# 나는 파이썬을 좋아합니다.

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# lang = "파이썬"
# print("나는 %s을 좋아합니다." % lang)
# ```
#
# </details>

# %% [markdown]
# **문제 5-3 [중급]**
#
# 실수 `3.14159` 를 소수점 2자리까지 출력하세요. (결과: `3.14`)

# %%
# 여기에 코드를 작성하세요
pi = 3.14159
print("%0.2f" %pi)
# Out:
# 3.14

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# pi = 3.14159
# print("%.2f" % pi)
# ```
#
# </details>

# %% [markdown]
# **문제 5-4 [중급]**
#
# `format()` 함수를 사용해 `3 + 4 = 7` 을 출력하세요.

# %%
# 여기에 코드를 작성하세요
print("{0} + {1} = {2}".format(3,4,(3+4)))
# Out:
# 3 + 4 = 7

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# print("{0} + {1} = {2}".format(3, 4, 3 + 4))
# ```
#
# </details>

# %% [markdown]
# **문제 5-5 [고급]**
#
# `%%` 를 사용해 `성공률: 90%` 를 출력하고, 그 아래 줄에 `3.14159` 를 폭 10, 소수점 2자리로 오른쪽 정렬해 출력하세요.

# %%
# 여기에 코드를 작성하세요
print("성공률 : %d%%" %90)
print("%10.2f" %3.141592)
# Out:
# 성공률 : 90%
#       3.14

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# print("성공률: %d%%" % 90)
# print("%10.2f" % 3.14159)
# ```
#
# </details>

# %% [markdown]
# ## 6. 연산자

# %% [markdown]
# **문제 6-1 [초급]**
#
# `a = 10`, `b = 3` 일 때 덧셈, 뺄셈, 곱셈 결과를 한 줄에 출력하세요. (결과: `13 7 30`)

# %%
# 여기에 코드를 작성하세요
a = 10
b = 3
print(a+b, a-b, a*b)
# Out:
# 13 7 30

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# a = 10
# b = 3
# print(a + b, a - b, a * b)
# ```
#
# </details>

# %% [markdown]
# **문제 6-2 [초급]**
#
# `17` 을 `5` 로 나눈 몫과 나머지를 한 줄에 출력하세요. (결과: `3 2`)

# %%
# 여기에 코드를 작성하세요
a = 17
b = 5
print(a//b, a%b)
# Out:
# 3 2

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# print(17 // 5, 17 % 5)
# ```
#
# </details>

# %% [markdown]
# **문제 6-3 [중급]**
#
# `2` 의 `10` 제곱을 출력하세요. (결과: `1024`)

# %%
# 여기에 코드를 작성하세요
print(2**10)
# Out:
# 1024

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# print(2 ** 10)
# ```
#
# </details>

# %% [markdown]
# **문제 6-4 [중급]**
#
# 변수 `a = 5` 에 복합 대입 연산자를 사용해 3을 더한 뒤 2를 곱하고 결과를 출력하세요. (결과: `16`)

# %%
# 여기에 코드를 작성하세요
a = 5
a += 3
a *= 2
print(a)
# Out:
# 16

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# a = 5
# a += 3
# a *= 2
# print(a)
# ```
#
# </details>

# %% [markdown]
# **문제 6-5 [고급]**
#
# 초 단위 정수를 입력받아 `O분 O초` 형식으로 출력하세요. (예: `125` -> `2분 5초`)

# %%
# 여기에 코드를 작성하세요
sec = int(input())
print("%d분 %d초" %(sec//60, sec%60))
# Out:
# 2분 5초

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# sec = int(input())
# print("%d분 %d초" % (sec // 60, sec % 60))
# ```
#
# </details>

# %% [markdown]
# ## 7. 문자열 다루기

# %% [markdown]
# **문제 7-1 [초급]**
#
# 문자열 `"Python"` 의 첫 글자와 마지막 글자를 한 줄에 출력하세요. (결과: `P n`)

# %%
# 여기에 코드를 작성하세요
a = "Python"
print(a[0], a[-1])
# Out:
# P n

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# s = "Python"
# print(s[0], s[-1])
# ```
#
# </details>

# %% [markdown]
# **문제 7-2 [초급]**
#
# 문자열 `"programming"` 의 앞 4글자를 슬라이싱으로 출력하세요. (결과: `prog`)

# %%
# 여기에 코드를 작성하세요
a = "programming"
print(a[0:4])
# Out:
# prog

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# s = "programming"
# print(s[:4])
# ```
#
# </details>

# %% [markdown]
# **문제 7-3 [중급]**
#
# 문자열 `"hello"` 를 거꾸로 뒤집어 출력하세요. (결과: `olleh`)

# %%
# 여기에 코드를 작성하세요
a = "hello"
print(a[::-1])
# Out:
# olleh

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# s = "hello"
# print(s[::-1])
# ```
#
# </details>

# %% [markdown]
# **문제 7-4 [중급]**
#
# 문자열 `"Hello"` 를 모두 대문자, 모두 소문자로 각각 출력하세요.

# %%
# 여기에 코드를 작성하세요
a = "Hello"
print(a.upper(), a.lower())
# Out:
# HELLO hello

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# s = "Hello"
# print(s.upper(), s.lower())
# ```
#
# </details>

# %% [markdown]
# **문제 7-5 [중급]**
#
# `"I like cats"` 에서 `cats` 를 `dogs` 로 바꿔 출력하세요.

# %%
# 여기에 코드를 작성하세요
a = "I like cats"
print(a.replace("cats", "dogs"))
# Out:
# I like dogs

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# s = "I like cats"
# print(s.replace("cats", "dogs"))
# ```
#
# </details>

# %% [markdown]
# **문제 7-6 [중급]**
#
# 문자열 `"banana"` 에서 `a` 의 개수와 `n` 이 처음 나오는 위치를 출력하세요.

# %%
# 여기에 코드를 작성하세요
a = "banana"
print(a.count('a'), a.index('n'))
# Out:
# 3 2

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# s = "banana"
# print(s.count("a"), s.find("n"))
# ```
#
# </details>

# %% [markdown]
# **문제 7-7 [고급]**
#
# 문자열 `"a,b,c,d"` 를 쉼표로 나눈 뒤 하이픈으로 다시 이어 출력하세요. (결과: `a-b-c-d`)

# %%
# 여기에 코드를 작성하세요
s = "a, b, c, d"
print('-'.join(s.split(',')))
# Out:
# a- b- c- d

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# s = "a,b,c,d"
# print("-".join(s.split(",")))
# ```
#
# </details>

# %% [markdown]
# **문제 7-8 [고급]**
#
# 주민등록번호 문자열 `"990101-2234567"` 에서 생년월일 6자리와 성별 숫자 1자리를 각각 출력하세요.

# %%
# 여기에 코드를 작성하세요
num = input()
print(num[0:6])
print(num[8])
# Out:
# 990101
# 2

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# num = "990101-2234567"
# print("생년월일:", num[:6])
# print("성별숫자:", num[7])
# ```
#
# </details>

# %% [markdown]
# ## 8. 리스트

# %% [markdown]
# **문제 8-1 [초급]**
#
# 과일 세 개를 담은 리스트를 만들어 통째로 출력하세요.

# %%
# 여기에 코드를 작성하세요
li = ['apple', 'banana', 'kiwi']
print(li)
# Out:
# ['apple', 'banana', 'kiwi']

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# fruits = ["apple", "banana", "cherry"]
# print(fruits)
# ```
#
# </details>

# %% [markdown]
# **문제 8-2 [초급]**
#
# 리스트 `[10, 20, 30]` 의 두 번째 값을 `200` 으로 바꾼 뒤 출력하세요.

# %%
# 여기에 코드를 작성하세요
li = [10,20,30]
li[1] = 200
print(li)
# Out:
# [10, 200, 30]

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# a = [10, 20, 30]
# a[1] = 200
# print(a)
# ```
#
# </details>

# %% [markdown]
# **문제 8-3 [중급]**
#
# 리스트 `[1, 2, 3]` 의 맨 뒤에 `4` 를 추가해 출력하세요.

# %%
# 여기에 코드를 작성하세요
li = [1,2,3]
li.append(4)
print(li)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# a = [1, 2, 3]
# a.append(4)
# print(a)
# ```
#
# </details>

# %% [markdown]
# **문제 8-4 [중급]**
#
# 리스트 `[3, 1, 2]` 를 오름차순 정렬한 뒤, 다시 역순으로 뒤집어 각각 출력하세요.

# %%
# 여기에 코드를 작성하세요
li = [3,1,2]
li.sort()
li.reverse()
print(li)
# Out:
# [3, 2, 1]

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# a = [3, 1, 2]
# a.sort()
# print(a)
# a.reverse()
# print(a)
# ```
#
# </details>

# %% [markdown]
# **문제 8-5 [중급]**
#
# 리스트 `[1, 2, 3, 4, 5]` 에서 두 번째부터 네 번째 값까지 슬라이싱해 출력하세요. (결과: `[2, 3, 4]`)

# %%
# 여기에 코드를 작성하세요
li = [1,2,3,4,5]
print(li[1:4])
# Out:
# [2, 3, 4]

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# a = [1, 2, 3, 4, 5]
# print(a[1:4])
# ```
#
# </details>

# %% [markdown]
# **문제 8-6 [중급]**
#
# 리스트 `[10, 20, 30, 40]` 의 요소 개수와 합을 출력하세요. (결과: `4 100`)

# %%
# 여기에 코드를 작성하세요
li =[10,20,30,40]
print(len(li), sum(li))
# Out:
# 4 100

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# a = [10, 20, 30, 40]
# print(len(a), sum(a))
# ```
#
# </details>

# %% [markdown]
# **문제 8-7 [고급]**
#
# 리스트 `[3, 7, 2, 9, 5]` 에서 최댓값과 최솟값의 차이를 출력하세요. (결과: `7`)

# %%
# 여기에 코드를 작성하세요
li = [3,7,2,9,5]
print(max(li) - min(li))
# Out:
# 7

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# a = [3, 7, 2, 9, 5]
# print(max(a) - min(a))
# ```
#
# </details>

# %% [markdown]
# **문제 8-8 [고급]**
#
# 중첩 리스트 `[1, [2, 3], [4, [5, 6]]]` 에서 값 `5` 를 인덱싱으로 꺼내 출력하세요.

# %%
# 여기에 코드를 작성하세요
li = [1,[2,3],[4,[5,6]]]
print(li[2][1][0])
# Out:
# 5

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# a = [1, [2, 3], [4, [5, 6]]]
# print(a[2][1][0])
# ```
#
# </details>

# %% [markdown]
# ## 9. 튜플

# %% [markdown]
# **문제 9-1 [초급]**
#
# 튜플 `(10, 20, 30)` 의 첫 값과 마지막 값을 출력하세요.

# %%
# 여기에 코드를 작성하세요
t1 = (10,20,30)
print(t1[0], t1[-1])
# Out:
# 10 30

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# t = (10, 20, 30)
# print(t[0], t[-1])
# ```
#
# </details>

# %% [markdown]
# **문제 9-2 [중급]**
#
# 튜플 `(1, 2)` 에 `(3, 4)` 를 이어 붙인 결과와, `(1, 2)` 를 3번 반복한 결과를 각각 출력하세요.

# %%
# 여기에 코드를 작성하세요
t = (1,2)
print(t + (3,4))
print(t*3)
# Out:
# (1, 2, 3, 4)
# (1, 2, 1, 2, 1, 2)

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# t = (1, 2)
# print(t + (3, 4))
# print(t * 3)
# ```
#
# </details>

# %% [markdown]
# **문제 9-3 [고급]**
#
# 좌표 튜플 `(3, 5)` 를 언패킹하여 `x=3, y=5` 형식으로 출력하세요.

# %%
# 여기에 코드를 작성하세요
t = (3,5)
x , y = t
print("x = %d, y = %d" %(x,y))
# Out:
# x = 3, y = 5

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# point = (3, 5)
# x, y = point
# print("x=%d, y=%d" % (x, y))
# ```
#
# </details>

# %% [markdown]
# ## 10. 딕셔너리

# %% [markdown]
# **문제 10-1 [초급]**
#
# `{"name": "홍길동", "age": 13}` 딕셔너리에서 이름을 꺼내 출력하세요.

# %%
# 여기에 코드를 작성하세요
dic = {"name" : "홍길동", "age" : 13}
print(dic["name"])
# Out:
# 홍길동

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# d = {"name": "홍길동", "age": 13}
# print(d["name"])
# ```
#
# </details>

# %% [markdown]
# **문제 10-2 [중급]**
#
# 딕셔너리 `{"a": 1}` 에 `"b": 2` 를 추가하고 `"a"` 를 삭제한 뒤 출력하세요. (결과: `{'b': 2}`)

# %%
# 여기에 코드를 작성하세요
dic = {"a" : 1}
dic["b"] = 2
del dic["a"]
print(dic)
# Out:
# {'b': 2}

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# d = {"a": 1}
# d["b"] = 2
# del d["a"]
# print(d)
# ```
#
# </details>

# %% [markdown]
# **문제 10-3 [중급]**
#
# 딕셔너리 `{"a": 1, "b": 2}` 의 key 목록과 value 목록을 각각 리스트로 출력하세요.

# %%
# 여기에 코드를 작성하세요
dic = {"a" : 1, "b" : 2}
print(dic.keys())
print(dic.values())
# Out:
# dict_keys(['a', 'b'])
# dict_values([1, 2])

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# d = {"a": 1, "b": 2}
# print(list(d.keys()), list(d.values()))
# ```
#
# </details>

# %% [markdown]
# **문제 10-4 [고급]**
#
# 영한사전 `{"apple": "사과", "banana": "바나나"}` 를 만들고, 영어 단어를 입력받아 뜻을 출력하세요.

# %%
# 여기에 코드를 작성하세요
dic = {"apple" : "사과", "banana" : "바나나"}
a = input()
print(dic[a])
# Out:
# 사과

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# eng2kor = {"apple": "사과", "banana": "바나나"}
# word = input()
# print(eng2kor[word])
# ```
#
# </details>

# %% [markdown]
# ## 11. 세트 (집합)

# %% [markdown]
# **문제 11-1 [초급]**
#
# 리스트 `[1, 2, 2, 3, 3, 3]` 을 세트로 만들어 중복을 제거한 결과를 출력하세요.

# %%
# 여기에 코드를 작성하세요
li = [1,2,2,3,3,3]
s = set(li)
print(s)
# Out:
# {1, 2, 3}

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# nums = [1, 2, 2, 3, 3, 3]
# print(set(nums))
# ```
#
# </details>

# %% [markdown]
# **문제 11-2 [중급]**
#
# 세트 `{1, 2, 3, 4}` 와 `{3, 4, 5, 6}` 의 합집합, 교집합, 차집합을 각각 출력하세요.

# %%
# 여기에 코드를 작성하세요
s1 = set([1,2,3,4])
s2 = set([3,4,5,6])

print(s1 | s2)
print(s1 & s2)
print(s1 - s2)
# Out:
# {1, 2, 3, 4, 5, 6}
# {3, 4}
# {1, 2}

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# a = {1, 2, 3, 4}
# b = {3, 4, 5, 6}
# print(a | b)
# print(a & b)
# print(a - b)
# ```
#
# </details>

# %% [markdown]
# **문제 11-3 [고급]**
#
# 두 리스트 `[1, 2, 3, 4]` 와 `[3, 4, 5]` 의 공통 원소를 세트로 출력하세요.

# %%
# 여기에 코드를 작성하세요
s1 = set([1,2,3,4])
s2 = set([3,4,5])
print(s1 & s2)
# Out:
# {3, 4}

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# a = [1, 2, 3, 4]
# b = [3, 4, 5]
# print(set(a) & set(b))
# ```
#
# </details>

# %% [markdown]
# ## 12. 종합 문제

# %% [markdown]
# **문제 12-1 [중급]**
#
# 문장을 입력받아 단어가 몇 개인지 출력하세요. (예: `I love python` -> `3`)

# %%
# 여기에 코드를 작성하세요
s = "I love python"
print(len(s.split()))
# Out:
# 3

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# s = input()
# print(len(s.split()))
# ```
#
# </details>

# %% [markdown]
# **문제 12-2 [중급]**
#
# 성과 이름을 각각 입력받아 이니셜을 대문자로 출력하세요. (예: `hong`, `gildong` -> `HG`)

# %%
# 여기에 코드를 작성하세요
a = input()
b = input()
print(a[0].upper(), b[0].upper(), sep = "")
# Out:
# HG

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# first = input()
# last = input()
# print((first[0] + last[0]).upper())
# ```
#
# </details>

# %% [markdown]
# **문제 12-3 [고급]**
#
# 단어를 입력받아 글자 수와 대문자로 바꾼 결과를 출력하세요.

# %%
# 여기에 코드를 작성하세요
word = input()
print(len(word))
print(word.upper())
# Out:
# 5
# HELLO

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# s = input()
# print("길이:", len(s))
# print("대문자:", s.upper())
# ```
#
# </details>

# %% [markdown]
# **문제 12-4 [고급]**
#
# 이름 리스트 `["철수", "영희"]` 와 점수 리스트 `[90, 80]` 을 하나의 딕셔너리로 묶어 출력하세요. (결과: `{'철수': 90, '영희': 80}`)

# %%
# 여기에 코드를 작성하세요
name = ["철수" , "영희"]
score = [90,80]

print(dict(zip(name, score)))
# Out:
# {'철수': 90, '영희': 80}

# %% [markdown]
# <details>
# <summary><b>정답 예시 보기</b></summary>
#
# ```python
# names = ["철수", "영희"]
# scores = [90, 80]
# print(dict(zip(names, scores)))
# ```
#
# </details>

# %% [markdown]
# ---
# 수고하셨습니다!
